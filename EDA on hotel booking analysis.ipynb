# %%
#Importing Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
#Mounting drive
from google.colab import drive     
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#csv file location
file_path= "/content/drive/MyDrive/Colab Notebooks/Capstone Project/Hotel Bookings.csv"

# %%
# reading csv file
df= pd.read_csv(file_path)

# %%
#Reading first 5 rows
pd.set_option('display.max_columns',None)
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
#Looking for last 5 rows

df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
#Getting info about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
#Checking for mean,std and max values

df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
#Creating copy of data

data=df.copy()

# %%
#Checking for duplicate's

data.duplicated().value_counts()
# Out:
# False    87396
# True     31994
# dtype: int64

# %%
#Visualization for duplicate values

plt.figure(figsize=(10,6))
plt.pie(data.duplicated().value_counts(),labels=['False','True'],explode=[0.02,0.02],autopct='%1.1f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#Dropping duplicates from the dataset

data2=data.drop_duplicates()

# %%
# shape of dataset

data2.shape
# Out:
# (87396, 32)

# %%
#Checking for null values

data2.isnull().sum().sort_values(ascending=False).head()
# Out:
# company               82137
# agent                 12193
# country                 452
# children                  4
# reserved_room_type        0
# dtype: int64

# %%
#data2['company'].isnull().sum()*100/len(data2['company'])

# %%
#Filling null values of counrty by others
data2['country'].fillna('others',inplace=True)

# %%
#Value counts for country
data2['country'].value_counts()
# Out:
# PRT    27453
# GBR    10433
# FRA     8837
# ESP     7252
# DEU     5387
#        ...
# MMR        1
# BFA        1
# CYM        1
# MLI        1
# KHM        1
# Name: country, Length: 178, dtype: int64

# %%
data2.isnull().sum().sort_values(ascending=False).head()
# Out:
# company                   82137
# agent                     12193
# children                      4
# hotel                         0
# previous_cancellations        0
# dtype: int64

# %%
#Checking for null values through heatmap

plt.figure(figsize=(25,10))
sns.heatmap(data2.isnull(),cbar=False,yticklabels=False,cmap='cividis')

# %%
#Replacing null values with 0

null_value=['agent','company','children']

for i in null_value:
    data2[i].fillna(0,inplace=True)

# %%
#Checking for null values
data2.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
#Checking for unique values of arrival date month
data2['arrival_date_month'].unique()
# Out:
# array(['July', 'August', 'September', 'October', 'November', 'December',
#        'January', 'February', 'March', 'April', 'May', 'June'],
#       dtype=object)

# %%
# Dropping the columns where adults,children and babies is 0.
len(data2[data2['adults']+data2['children']+data2['babies']==0])
data2.drop(data2[data2['adults']+data2['children']+data2['babies']==0].index,inplace=True)

# %%
#Adding for columns for total people and total stay

data2['total_people']=data2['adults']+data2['children']+data2['babies']
data2['total_stay']=data2['stays_in_week_nights']+data2['stays_in_weekend_nights']

# %% [markdown]
# EDA

# %%
plt.figure(figsize=(16,6))
sns.heatmap(data2.corr(),annot=True,cmap='viridis')

# %%
#Checking for which type of hotel booked most
sns.countplot(data2['hotel'])

# %% [markdown]
# City hotel are most prefer than resort hotel

# %%
sns.boxplot(y=data2['lead_time'],x=data2['stays_in_weekend_nights'])

# %%
#How many people canceled the bookings
plt.pie(data2['is_canceled'].value_counts(),labels=['no','yes'],colors=['orange','green'],explode=[0.03,0.03],autopct='%1.1f%%')
plt.show()

# %%
plt.figure(figsize=(12,6))

sns.countplot(data2['customer_type'],hue=data2['hotel'])
plt.show()

# %% [markdown]
# From the above, we can see the city hotels are more preferred for the transient customer. Whereas resort and city hotels are both booked almost same by Contract customer type. For the Transient party, they booked a city hotel over a resort hotel.Group hotel booked same for both hotel types.

# %%
data3=data2['country'].value_counts().head(10)
data3.plot(kind='bar',color='orange')
plt.xlabel('country')
plt.ylabel('No. of bookings')
plt.title('Top countries with most bookings')
plt.show()

# %%
#data2['is_repeated_guest'].unique()

# %%
plt.figure(figsize=(12,6))
plt.pie(data2['is_repeated_guest'].value_counts(),explode=[0.09,0.09],labels=[0,1],autopct='%1.1f%%')
plt.title('Repeated Guest')
plt.show()

# %% [markdown]
# Repeated guests are very few i.e only 3.9 %

# %%
data2['required_car_parking_spaces'].unique()
# Out:
# array([0, 1, 2, 8, 3])

# %%
sns.set_style('darkgrid')
sns.countplot(data2['required_car_parking_spaces'])

# %% [markdown]
# Very few people required car parking spaces

# %%
highest_bookings=data2.groupby(['agent'])['agent'].agg({'count'}).reset_index().rename(columns={'count':'Most Booking'}).sort_values(by='Most Booking',ascending=False)

# %%
highest_bookings.drop(highest_bookings[highest_bookings['agent']==0].index,inplace=True)

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=highest_bookings['agent'][:10],y=highest_bookings['Most Booking'][:10],order=highest_bookings['agent'][:10])

# %%
plt.figure(figsize=(12,6))
plt.pie(data2['deposit_type'].value_counts(),labels=data2['deposit_type'].value_counts().index.tolist(),explode=[0.2,0.3,0.5],autopct='%1.1f%%')
plt.title('Deposit Type')
plt.show()

# %% [markdown]
# 98.7  of the guest prefer no deposit over other type pf deposit

# %%
plt.figure(figsize=(12,6))
sns.countplot(data2['meal'])
plt.xlabel('meal type')
plt.title('Meal type')
# Out:
# Text(0.5, 1.0, 'Meal type')

# %% [markdown]
# 1) so BB is most prefered meal over all type.
# 2) HB and sc are equally preferred

# %% [markdown]
# plot for best time of year to book hotel room

# %%
sns.displot(data2['arrival_date_month'],aspect=2,color='green')

# %%
sns.countplot(data2['reserved_room_type'])

# %% [markdown]
# predict for wheather or not hotel receives special request

# %%
sns.displot(data2['total_of_special_requests'],bins=20)

# %%
sns.barplot(x=df['stays_in_week_nights'],y=df['stays_in_weekend_nights'])

# %%
sns.countplot(data=data2,x='arrival_date_year')

# %%
plt.rcParams['figure.figsize']=(14,6)
sns.lineplot(x=data2['arrival_date_month'],y=data2['is_canceled'])

# %%
sns.lineplot(x=data2['arrival_date_month'].sort_values(ascending=True),y=data2['adr'],hue=data2['hotel'])

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x=data2['market_segment'],y=data2['days_in_waiting_list'])

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=data2['distribution_channel'],y=data2['adr'],hue=data2['hotel'])
plt.legend()

# %% [markdown]
# Direct and TA/TO has contributed more in adr in both hotels i.e Resort hotel and city hotels. GDS has highly contributed in city hotels and need to expand bookings in Resort hote

# %%
sns.countplot(x=data2['distribution_channel'],hue=data2['is_canceled'])

# %% [markdown]
# As we can see that TA/TO has cancelled most bookings

# %% [markdown]
# CONCLUSION :
# 1) City hotels are booked most as compare to Resort hotels. 2) Cancellation of a hotel is 27.5% whereas those who did not cancel is at 72.5 % 3) City hotels are more preferred for the transient customer. Whereas resort and city hotels are both booked almost same by Contract customer type. For the Transient party, they booked a city hotel over a resort hotel.Group hotel booked same for both hotel types. 4) Portugal having most booking for hotels. 5)Repeated guest are only 3.9 % and new customers are 96.1% 6) Maximum people dont need car parking only few needs car parking for 1 car. 7) Agent number 9 make most bookings. 8) People often chose no deposite type over other 9) BB is most liked meal among all.HB and SC are almost at same level. 10)Most people arrival date is in August. 11)Room type A is most reserved room type after that room type D is most reserved 12)Many people did not ask for special request but few asked for 1 request. 12) 2016 has most bookings for hotel. 14)TA/TO has contributed more in adr.GDS has highly contributed in city hotels and need to expand bookings in Resort hotel. 15)August has most number of cancelation. 16)TA/TO has most number of cancelation.
